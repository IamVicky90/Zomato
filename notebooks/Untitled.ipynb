# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Data Preprocessing

# %%
df=pd.read_csv('../Master_Training_File/Zomato.csv') #Convert csv file to Pandas DataFrame

# %%
df.head(7) #Looking at the head
# Out:
#    serial                                                url  \
# 0     0.0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1     1.0  https://www.zomato.com/bangalore/spice-elephan...
# 2     2.0  https://www.zomato.com/SanchurroBangalore?cont...
# 3     3.0  https://www.zomato.com/bangalore/addhuri-udupi...
# 4     4.0  https://www.zomato.com/bangalore/grand-village...
# 5     5.0  https://www.zomato.com/bangalore/timepass-dinn...
# 6     6.0  https://www.zomato.com/bangalore/rosewood-inte...
#
#                                              address  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2  1112, Next to KIMS Medical College, 17th Cross...
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6  19/1, New Timberyard Layout, Beside Satellite ...
#
# ...

# %%
df.drop(['serial','name','url','address','phone','phone','reviews_list'],axis=1,inplace=True) #Removing wome unwanted columns

# %%
df.info() #Getting info. about data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   name                        1000 non-null   object
#  1   online_order                1000 non-null   object
#  2   book_table                  1000 non-null   object
#  3   rate                        900 non-null    object
#  4   votes                       1000 non-null   float64
#  5   location                    1000 non-null   object
#  6   rest_type                   999 non-null    object
#  7   dish_liked                  453 non-null    object
#  8   cuisines                    997 non-null    object
#  9   approx_cost_for_two_people  1000 non-null   object
#  10  menu_item                   1000 non-null   object
#  11  listed_in_type              1000 non-null   object
#  12  listed_in_city              1000 non-null   object
# ...

# %%
df.isnull().sum() #Looking for the null values
# Out:
# name                            0
# online_order                    0
# book_table                      0
# rate                          100
# votes                           0
# location                        0
# rest_type                       1
# dish_liked                    547
# cuisines                        3
# approx_cost_for_two_people      0
# menu_item                       0
# listed_in_type                  0
# listed_in_city                  0
# dtype: int64

# %%
df.cuisines.value_counts()
# Out:
# South Indian                                    89
# North Indian, Chinese                           47
# North Indian                                    47
# South Indian, North Indian, Chinese             24
# Fast Food                                       21
#                                                 ..
# Biryani, North Indian, Kebab                     1
# North Indian, Seafood, Chinese                   1
# Cafe, Bakery, Beverages                          1
# South Indian, Burger                             1
# Mithai, South Indian, Street Food, Fast Food     1
# Name: cuisines, Length: 344, dtype: int64
